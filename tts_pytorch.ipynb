# %%
# Fast install, might break in the future.
# !pip install 'sphn<0.2'
# !pip install --no-deps "moshi==0.2.7"
# Slow install (will download torch and cuda), but future proof.
# !pip install "moshi==0.2.7"
# Out:
# Collecting sphn<0.2
#   Downloading sphn-0.1.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Downloading sphn-0.1.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 112.5 MB/s eta 0:00:00
# Installing collected packages: sphn
# Successfully installed sphn-0.1.12
# Collecting moshi==0.2.7
#   Downloading moshi-0.2.7-py3-none-any.whl.metadata (8.2 kB)
# Downloading moshi-0.2.7-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.1/107.1 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: moshi
# Successfully installed moshi-0.2.7

# %%
import argparse
import sys

import numpy as np
import torch
from moshi.models.loaders import CheckpointInfo
from moshi.models.tts import DEFAULT_DSM_TTS_REPO, DEFAULT_DSM_TTS_VOICE_REPO, TTSModel

from IPython.display import display, Audio

# %%
# Configuration
text = "Hey there! How are you? I had the craziest day today."
voice = "expresso/ex03-ex01_happy_001_channel1_334s.wav"
print(f"See https://huggingface.co/{DEFAULT_DSM_TTS_VOICE_REPO} for available voices.")
# Out:
# See https://huggingface.co/kyutai/tts-voices for available voices.

# %%
# Set everything up
checkpoint_info = CheckpointInfo.from_hf_repo(DEFAULT_DSM_TTS_REPO)
tts_model = TTSModel.from_checkpoint_info(
    checkpoint_info, n_q=32, temp=0.6, device=torch.device("cuda"), dtype=torch.half
)

# If you want to make a dialog, you can pass more than one turn [text_speaker_1, text_speaker_2, text_2_speaker_1, ...]
entries = tts_model.prepare_script([text], padding_between=1)
voice_path = tts_model.get_voice_path(voice)
print(voice_path)
# CFG coef goes here because the model was trained with CFG distillation,
# so it's not _actually_ doing CFG at inference time.
# Also, if you are generating a dialog, you should have two voices in the list.
condition_attributes = tts_model.make_condition_attributes(
    [voice_path], cfg_coef=2.0
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# dsm_tts_1e68beda%40240.safetensors:   0%|          | 0.00/3.68G [00:00<?, ?B/s]
# (…)nizer-e351c8d8-checkpoint125.safetensors:   0%|          | 0.00/385M [00:00<?, ?B/s]
# tokenizer_spm_8k_en_fr_audio.model:   0%|          | 0.00/120k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-5-388049898.py in <cell line: 0>()
#       1 # Set everything up
#       2 checkpoint_info = CheckpointInfo.from_hf_repo(DEFAULT_DSM_TTS_REPO)
# ----> 3 tts_model = TTSModel.from_checkpoint_info(
#       4     checkpoint_info, n_q=32, temp=0.6, device=torch.device("cuda"), dtype=torch.half
#       5 )
#
# /usr/local/lib/python3.11/dist-packages/moshi/models/tts.py in from_checkpoint_info(checkpoint_info, initial_padding, max_padding, voice_repo, device, dtype, **kwargs)
#     394         voice_suffix = f".{model_id['sig']}@{model_id['epoch']}.safetensors"
#     395
# --> 396         mimi = checkpoint_info.get_mimi(device=device)
#     397         tokenizer = checkpoint_info.get_text_tokenizer()
#     398         lm = checkpoint_info.get_moshi(device=device, dtype=dtype)
#
# /usr/local/lib/python3.11/dist-packages/moshi/models/loaders.py in get_mimi(self, device)
#     260         else:
#     261             num_codebooks = max(self.lm_config["dep_q"], self.lm_config["n_q"] - self.lm_config["dep_q"])
# --> 262         return get_mimi(self.mimi_weights, num_codebooks=num_codebooks, device=device)
#     263
#     264     def get_moshi(
#
# /usr/local/lib/python3.11/dist-packages/moshi/models/loaders.py in get_mimi(filename, device, num_codebooks)
#     298     encoder = SEANetEncoder(**_seanet_kwargs)
#     299     decoder = SEANetDecoder(**_seanet_kwargs)
# --> 300     encoder_transformer = transformer.ProjectedTransformer(
#     301         device=device, **_transformer_kwargs
#     302     )
#
# /usr/local/lib/python3.11/dist-packages/moshi/modules/transformer.py in __init__(self, input_dimension, output_dimensions, d_model, conv_layout, **kwargs)
#     925     ):
#     926         super().__init__()
# --> 927         self.transformer = StreamingTransformer(d_model=d_model, **kwargs)
#     928         self.input_dimension = input_dimension
#     929         self.output_dimensions = output_dimensions
#
# /usr/local/lib/python3.11/dist-packages/moshi/modules/transformer.py in __init__(self, d_model, num_heads, num_layers, dim_feedforward, causal, context, positional_embedding, max_period, positional_scale, betas, layer_class, quantize, checkpointing, device, dtype, **kwargs)
#     844         for _ in range(num_layers):
#     845             self.layers.append(
# --> 846                 layer_class(
#     847                     d_model=d_model,
#     848                     num_heads=num_heads,
#
# /usr/local/lib/python3.11/dist-packages/moshi/modules/transformer.py in __init__(self, d_model, num_heads, dim_feedforward, causal, context, rope, norm, layer_scale, gating, weights_per_step, weights_per_step_schedule, activation, skip_self_attn, cross_attention, device, dtype)
#     635         }
#     636         if not skip_self_attn:
# --> 637             self.self_attn: StreamingMultiheadAttention = StreamingMultiheadAttention(
#     638                 causal=causal,
#     639                 context=context,
#
# /usr/local/lib/python3.11/dist-packages/moshi/modules/transformer.py in __init__(self, embed_dim, num_heads, causal, context, rope, weights_per_step, weights_per_step_schedule, cross_attention, cache_cross_attention, device, dtype)
#     392         # Split in one linear per step
#     393         self.out_projs = nn.ModuleList(
# --> 394             [
#     395                 nn.Linear(embed_dim, embed_dim, bias=False, **factory_kwargs)
#     396                 for _ in range(mult)
#
# /usr/local/lib/python3.11/dist-packages/moshi/modules/transformer.py in <listcomp>(.0)
#     393         self.out_projs = nn.ModuleList(
#     394             [
# --> 395                 nn.Linear(embed_dim, embed_dim, bias=False, **factory_kwargs)
#     396                 for _ in range(mult)
#     397             ]
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in __init__(self, in_features, out_features, bias, device, dtype)
#     104         self.out_features = out_features
#     105         self.weight = Parameter(
# --> 106             torch.empty((out_features, in_features), **factory_kwargs)
#     107         )
#     108         if bias:
#
# /usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     317         if "CUDA_MODULE_LOADING" not in os.environ:
#     318             os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 319         torch._C._cuda_init()
#     320         # Some of the queued calls may reentrantly call _lazy_init();
#     321         # we need to just return without initializing in that case.
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
print("Generating audio...")

pcms = []
def _on_frame(frame):
    print("Step", len(pcms), end="\r")
    if (frame != -1).all():
        pcm = tts_model.mimi.decode(frame[:, 1:, :]).cpu().numpy()
        pcms.append(np.clip(pcm[0, 0], -1, 1))

# You could also generate multiple audios at once by extending the following lists.
all_entries = [entries]
all_condition_attributes = [condition_attributes]
with tts_model.mimi.streaming(len(all_entries)):
    result = tts_model.generate(all_entries, all_condition_attributes, on_frame=_on_frame)

print("Done generating.")
audio = np.concatenate(pcms, axis=-1)

# %%
display(
    Audio(audio, rate=tts_model.mimi.sample_rate, autoplay=True)
)
